# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
os.chdir('C:\\Users\\DELL\\Desktop\\Data Framing')

# %%
dataset = pd.read_csv('middle_tn_schools.csv')

# %%
dataset
# Out:
#                                             name  school_rating    size  \
# 0                    Allendale Elementary School            5.0   851.0
# 1                            Anderson Elementary            2.0   412.0
# 2                               Avoca Elementary            4.0   482.0
# 3                                  Bailey Middle            0.0   394.0
# 4                            Barfield Elementary            4.0   948.0
# 5                 Barkers Mill Elementary School            4.0   893.0
# 6                           Barksdale Elementary            4.0   580.0
# 7                               Beech Elementary            5.0   612.0
# 8                       Beech Senior High School            4.0  1274.0
# 9                                Bellevue Middle            3.0   680.0
# 10                          Bellshire Elementary            0.0   539.0
# 11              Benny C. Bills Elementary School            3.0   705.0
# ...

# %%
dataset.isnull().sum()
# Out:
# name                   0
# school_rating          0
# size                   0
# reduced_lunch          0
# state_percentile_16    0
# state_percentile_15    6
# stu_teach_ratio        0
# school_type            0
# avg_score_15           6
# avg_score_16           0
# full_time_teachers     0
# percent_black          0
# percent_white          0
# percent_asian          0
# percent_hispanic       0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(y='reduced_lunch', data=dataset)

# %%
dataset_1 = pd.DataFrame.describe(dataset)

# %%
dataset_1
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
dataset_2 = dataset.groupby(['school_rating']).size()

# %%
dataset_2
# Out:
# school_rating
# 0.0    43
# 1.0    40
# 2.0    44
# 3.0    56
# 4.0    86
# 5.0    78
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.lmplot(data=dataset, x='reduced_lunch', y='school_rating', fit_reg=True)

# %%
plt.scatter(data=dataset,  x='reduced_lunch', y='school_rating')

# %%
dataset_3=dataset[['reduced_lunch','school_rating']]

# %%
dataset_3
# Out:
#      reduced_lunch  school_rating
# 0             10.0            5.0
# 1             71.0            2.0
# 2             43.0            4.0
# 3             91.0            0.0
# 4             26.0            4.0
# 5             48.0            4.0
# 6             58.0            4.0
# 7             16.0            5.0
# 8             21.0            4.0
# 9             50.0            3.0
# 10            75.0            0.0
# 11            67.0            3.0
# 12            72.0            3.0
# 13            25.0            5.0
# 14            25.0            4.0
# 15            30.0            4.0
# 16            66.0            2.0
# 17            63.0            3.0
# 18            61.0            4.0
# 19            84.0            1.0
# 20             4.0            5.0
# 21             3.0            5.0
# 22            37.0            4.0
# 23            44.0            4.0
# 24            81.0            0.0
# 25            70.0            3.0
# ...

# %%
plt.scatter(data=dataset_3,x='reduced_lunch',y='school_rating')

# %%
x=dataset_3.iloc[0:,:].values

# %%
x
# Out:
# array([[10.,  5.],
#        [71.,  2.],
#        [43.,  4.],
#        [91.,  0.],
#        [26.,  4.],
#        [48.,  4.],
#        [58.,  4.],
#        [16.,  5.],
#        [21.,  4.],
#        [50.,  3.],
#        [75.,  0.],
#        [67.,  3.],
#        [72.,  3.],
#        [25.,  5.],
#        [25.,  4.],
#        [30.,  4.],
#        [66.,  2.],
#        [63.,  3.],
#        [61.,  4.],
#        [84.,  1.],
#        [ 4.,  5.],
#        [ 3.,  5.],
#        [37.,  4.],
#        [44.,  4.],
#        [81.,  0.],
#        [70.,  3.],
#        [74.,  2.],
#        [83.,  0.],
#        [90.,  0.],
#        [21.,  5.],
#        [42.,  2.],
#        [85.,  0.],
#        [45.,  3.],
#        [53.,  4.],
#        [60.,  4.],
#        [24.,  4.],
#        [79.,  1.],
#        [13.,  4.],
#        [79.,  1.],
#        [61.,  4.],
#        [30.,  4.],
#        [ 2.,  5.],
#        [52.,  2.],
#        [75.,  1.],
#        [56.,  3.],
#        [41.,  4.],
#        [54.,  2.],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x = sc_x.fit_transform(x)

# %%
x
# Out:
# array([[-1.58309773,  1.20365718],
#        [ 0.81437166, -0.57365789],
#        [-0.28610609,  0.61121882],
#        [ 1.6004272 , -1.7585346 ],
#        [-0.9542533 ,  0.61121882],
#        [-0.08959221,  0.61121882],
#        [ 0.30343556,  0.61121882],
#        [-1.34728107,  1.20365718],
#        [-1.15076719,  0.61121882],
#        [-0.01098666,  0.01878047],
#        [ 0.97158277, -1.7585346 ],
#        [ 0.65716055,  0.01878047],
#        [ 0.85367444,  0.01878047],
#        [-0.99355608,  1.20365718],
#        [-0.99355608,  0.61121882],
#        [-0.79704219,  0.61121882],
#        [ 0.61785778, -0.57365789],
#        [ 0.49994945,  0.01878047],
#        [ 0.42134389,  0.61121882],
#        [ 1.32530776, -1.16609624],
#        [-1.8189144 ,  1.20365718],
#        [-1.85821717,  1.20365718],
#        [-0.52192276,  0.61121882],
#        [-0.24680332,  0.61121882],
#        [ 1.20739943, -1.7585346 ],
#        [ 0.77506888,  0.01878047],
#        [ 0.93227999, -0.57365789],
# ...

# %%
data=pd.DataFrame(x)

# %%
data.plot()

# %%
sns.heatmap(data.corr(),cmap='coolwarm', annot=True)

# %%
sns.pairplot(dataset)
